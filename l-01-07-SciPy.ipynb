# %%
import numpy as np
import scipy
a = scipy.random.standard_normal((5,5))

b,c=np.linalg.eig(a)
print b
print c

print np.dot(a,b)
print a*b
print a*c
print np.dot(a,c)
# Out:
# [ 3.13357672+0.j         1.83993373+0.j        -0.16472954+0.j
#  -0.65003332+1.6795164j -0.65003332-1.6795164j]
# [[ 0.83311438+0.j         -0.56050646+0.j         -0.23890088+0.j
#   -0.16700109+0.26959121j -0.16700109-0.26959121j]
#  [-0.01062701+0.j         -0.02542470+0.j          0.12576716+0.j
#    0.63309782+0.j          0.63309782-0.j        ]
#  [ 0.15947813+0.j          0.14886049+0.j         -0.52506686+0.j
#    0.15336587-0.41802971j  0.15336587+0.41802971j]
#  [ 0.52774003+0.j          0.71722976+0.j         -0.01327413+0.j
#   -0.08190562+0.38601745j -0.08190562-0.38601745j]
#  [ 0.04318196+0.j          0.38549723+0.j          0.80699292+0.j
#   -0.09810548-0.36743129j -0.09810548+0.36743129j]]
# [ 8.52888274-3.34965j    -0.69407616+2.3922013j   2.43898665+1.55442855j
#  -0.98241589+0.05433974j  0.17760545+1.48617563j]
# [[ 9.35372904+0.j          0.31348029+0.j         -0.20587397+0.j
#    0.18199127-0.47021792j -1.11444389-2.87943207j]
# ...
